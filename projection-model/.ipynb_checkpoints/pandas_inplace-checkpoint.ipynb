# %%
import pandas as pd

# %%
df = pd.read_csv('../nba-stats-csv/player_stats_total.csv')

# %%
df_slim = df.sample(20)

# %%
df_slim
# Out:
#             player_name  player_id season_id    gp   age        min    fgm  \
# 1380   Luc Mbah a Moute     201601   2009-10  73.0  23.0  1866.3600  177.0
# 128      Chris Andersen       2365   2003-04  71.0  25.0  1028.5200   90.0
# 800     Marvin Williams     101107   2008-09  61.0  23.0  2093.4600  285.0
# 686            CJ Miles     101139   2007-08  60.0  21.0   689.4600  113.0
# 1804     Kevin Seraphin     202338   2011-12  57.0  22.0  1175.7800  203.0
# 362         James Jones       2592   2014-15  57.0  34.0   669.3720   74.0
# 2561       Delon Wright    1626153   2015-16  27.0  24.0   229.2420   36.0
# 368         Kyle Korver       2594   2006-07  74.0  26.0  2287.9600  372.0
# 116         Mike Miller       2034   2007-08  70.0  28.0  2474.1500  414.0
# 96       Jamal Crawford       2037   2004-05  70.0  25.0  2684.6400  437.0
# 471    Anderson Varejao       2760   2013-14  65.0  31.0  1800.2400  227.0
# ...

# %%
df_slim = df.sample(20)
